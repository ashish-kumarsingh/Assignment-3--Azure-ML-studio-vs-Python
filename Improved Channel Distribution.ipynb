# %%
#Importing Libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.externals import joblib
# Out:
# C:\Users\shahk\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
#Creating Dataset and including the first row by setting no header as input
dataset = pd.read_csv('C:/Users/shahk/OneDrive/Desktop/Apple vs Spotify/Email_Promotion_final1.csv')
#Renaming the columns
#dataset.columns = ['CustomerID','Plan Renew Status', 'Region','Age','Promotion Type','Channel']
print('Shape of the dataset: ' + str(dataset.shape))
print(dataset.head())
dataset.drop(columns=['customer_id','geo_group','Gender'])
# Out:
# Shape of the dataset: (25000, 6)
#     customer_id Gender      geo_group  age  Promotion Channel
# 0  SB0000024239      M  North America   42          3   Email
# 1  SB0000103256      M             EU   41          2   Email
# 2  SB0000115357      M  North America   42          1   Email
# 3  SB0000060380      F  North America   39          3   Email
# 4  SB0000138548      M           Asia   43          3   Email
#        age  Promotion   Channel
# 0       42          3     Email
# 1       41          2     Email
# 2       42          1     Email
# 3       39          3     Email
# 4       43          3     Email
# 5       44          2     Email
# 6       50          2     Email
# 7       29          3     Email
# 8       44          1     Email
# 9       27          2     Email
# 10      31          3     Email
# 11      24          1     Email
# 12      34          1     Email
# 13      25          2     Email
# 14      35          3     Email
# 15      45          3     Email
# ...

# %%
#Creating the dependent variable class
factor = pd.factorize(dataset['Channel'])
dataset.Channel = factor[0]
definitions = factor[1]
print(dataset.Channel.head())
print(definitions)
#########################
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Channel, dtype: int64
# Index(['Email', 'Google', 'FaceBook'], dtype='object')

# %%
#Splitting the data into independent and dependent variables
X = dataset.iloc[:,3:5].values
y = dataset.iloc[:,5].values
print('The independent features set: ')
print(X[:6,:])
print('The dependent variable: ')
print(y[:6])
# Out:
# The independent features set:
# [[42  3]
#  [41  2]
#  [42  1]
#  [39  3]
#  [43  3]
#  [44  2]]
# The dependent variable:
# [0 0 0 0 0 0]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 21)

# %%
# Feature Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
#Reverse factorize (converting y_pred from 0s,1s and 2s to google, FB, and Email
reversefactor = dict(zip(range(3),definitions))
y_test = np.vectorize(reversefactor.get)(y_test)
y_pred = np.vectorize(reversefactor.get)(y_pred)
# Making the Confusion Matrix
print(pd.crosstab(y_test, y_pred, rownames=['Actual Channel'], colnames=['Predicted Channel']))
# Out:
# Predicted Channel  Email  FaceBook  Google
# Actual Channel
# Email               2076       137     150
# FaceBook               8      1900       7
# Google                 5         8    1959

# %%
print("Train Acc =", classifier.score(X_train, y_train))
#print("Test Acc =", classifier.score(y_test, y_pred))
# calculate accuracy
from sklearn import metrics
print("Test Acc = ",metrics.accuracy_score(y_test, y_pred))
# Out:
# Train Acc = 0.9448
# Test Acc =  0.9496
